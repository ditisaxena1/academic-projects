# %%
# load some default Python modules
import numpy as np
import pandas as pd
import datetime as dt
import matplotlib.pyplot as plt
from pandas import DataFrame
from pandas import Series
import calendar
import datetime as dt
import seaborn as sns
# %matplotlib inline
plt.style.use('seaborn-whitegrid')

# %%
#Read the csv File and get total number of rows and coloumns
eq=pd.read_csv('C:\\Users\\ditsaxen\\Desktop\\Personal\\ISB CBA\\Session Material and Projects\\Projects\\Python project\\earthquake.csv')
eq.shape
# Out:
# (23412, 21)

# %%
#eq.info(verbose=True, null_counts=True)
eq.dtypes
# Out:
# Date                           object
# Time                           object
# Latitude                      float64
# Longitude                     float64
# Type                           object
# Depth                         float64
# Depth Error                   float64
# Depth Seismic Stations        float64
# Magnitude                     float64
# Magnitude Type                 object
# Magnitude Error               float64
# Magnitude Seismic Stations    float64
# Azimuthal Gap                 float64
# Horizontal Distance           float64
# Horizontal Error              float64
# Root Mean Square              float64
# ID                             object
# Source                         object
# Location Source                object
# Magnitude Source               object
# Status                         object
# dtype: object

# %%
eq.head(10)
# Out:
#          Date      Time  Latitude  Longitude        Type  Depth  Depth Error  \
# 0  01/02/1965  13:44:18    19.246    145.616  Earthquake  131.6          NaN
# 1  01/04/1965  11:29:49     1.863    127.352  Earthquake   80.0          NaN
# 2  01/05/1965  18:05:58   -20.579   -173.972  Earthquake   20.0          NaN
# 3  01/08/1965  18:49:43   -59.076    -23.557  Earthquake   15.0          NaN
# 4  01/09/1965  13:32:50    11.938    126.427  Earthquake   15.0          NaN
# 5  01/10/1965  13:36:32   -13.405    166.629  Earthquake   35.0          NaN
# 6  01/12/1965  13:32:25    27.357     87.867  Earthquake   20.0          NaN
# 7  01/15/1965  23:17:42   -13.309    166.212  Earthquake   35.0          NaN
# 8  01/16/1965  11:32:37   -56.452    -27.043  Earthquake   95.0          NaN
# 9  01/17/1965  10:43:17   -24.563    178.487  Earthquake  565.0          NaN
#
#    Depth Seismic Stations  Magnitude Magnitude Type  ...  \
# 0                     NaN        6.0             MW  ...
# ...

# %%
eq.describe()
# Out:
#            Latitude     Longitude         Depth  Depth Error  \
# count  23412.000000  23412.000000  23412.000000  4461.000000
# mean       1.679033     39.639961     70.767911     4.993115
# std       30.113183    125.511959    122.651898     4.875184
# min      -77.080000   -179.997000     -1.100000     0.000000
# 25%      -18.653000    -76.349750     14.522500     1.800000
# 50%       -3.568500    103.982000     33.000000     3.500000
# 75%       26.190750    145.026250     54.000000     6.300000
# max       86.005000    179.998000    700.000000    91.295000
#
#        Depth Seismic Stations     Magnitude  Magnitude Error  \
# count             7097.000000  23412.000000       327.000000
# mean               275.364098      5.882531         0.071820
# std                162.141631      0.423066         0.051466
# min                  0.000000      5.500000         0.000000
# 25%                146.000000      5.600000         0.046000
# ...

# %%
eq_filtered=eq[['Date','Time','Latitude','Longitude','Depth','Type','Magnitude']]
eq_filtered.head(20)
# Out:
#           Date      Time  Latitude  Longitude  Depth        Type  Magnitude
# 0   01/02/1965  13:44:18    19.246    145.616  131.6  Earthquake        6.0
# 1   01/04/1965  11:29:49     1.863    127.352   80.0  Earthquake        5.8
# 2   01/05/1965  18:05:58   -20.579   -173.972   20.0  Earthquake        6.2
# 3   01/08/1965  18:49:43   -59.076    -23.557   15.0  Earthquake        5.8
# 4   01/09/1965  13:32:50    11.938    126.427   15.0  Earthquake        5.8
# 5   01/10/1965  13:36:32   -13.405    166.629   35.0  Earthquake        6.7
# 6   01/12/1965  13:32:25    27.357     87.867   20.0  Earthquake        5.9
# 7   01/15/1965  23:17:42   -13.309    166.212   35.0  Earthquake        6.0
# 8   01/16/1965  11:32:37   -56.452    -27.043   95.0  Earthquake        6.0
# 9   01/17/1965  10:43:17   -24.563    178.487  565.0  Earthquake        5.8
# 10  01/17/1965  20:57:41    -6.807    108.988  227.9  Earthquake        5.9
# ...

# %%
eq_filtered.tail(10)
# Out:
#              Date      Time  Latitude  Longitude  Depth        Type  Magnitude
# 23402  12/24/2016  03:58:55   -5.1460   153.5166  30.00  Earthquake        5.8
# 23403  12/25/2016  14:22:27  -43.4029   -73.9395  38.00  Earthquake        7.6
# 23404  12/25/2016  14:32:13  -43.4810   -74.4771  14.93  Earthquake        5.6
# 23405  12/27/2016  23:20:56   45.7192    26.5230  97.00  Earthquake        5.6
# 23406  12/28/2016  08:18:01   38.3754  -118.8977  10.80  Earthquake        5.6
# 23407  12/28/2016  08:22:12   38.3917  -118.8941  12.30  Earthquake        5.6
# 23408  12/28/2016  09:13:47   38.3777  -118.8957   8.80  Earthquake        5.5
# 23409  12/28/2016  12:38:51   36.9179   140.4262  10.00  Earthquake        5.9
# 23410  12/29/2016  22:30:19   -9.0283   118.6639  79.00  Earthquake        6.3
# 23411  12/30/2016  20:08:28   37.3973   141.4103  11.94  Earthquake        5.5

# %%
eq_filtered['Type'].unique()
# Out:
# array(['Earthquake', 'Nuclear Explosion', 'Explosion', 'Rock Burst'],
#       dtype=object)

# %%
eq_filtered['Date']=pd.to_datetime(eq_filtered['Date'],utc=True)
# Out:
# C:\Users\ditsaxen\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
eq_filtered
# Out:
#                            Date      Time  Latitude  Longitude   Depth  \
# 0     1965-01-02 00:00:00+00:00  13:44:18   19.2460   145.6160  131.60
# 1     1965-01-04 00:00:00+00:00  11:29:49    1.8630   127.3520   80.00
# 2     1965-01-05 00:00:00+00:00  18:05:58  -20.5790  -173.9720   20.00
# 3     1965-01-08 00:00:00+00:00  18:49:43  -59.0760   -23.5570   15.00
# 4     1965-01-09 00:00:00+00:00  13:32:50   11.9380   126.4270   15.00
# 5     1965-01-10 00:00:00+00:00  13:36:32  -13.4050   166.6290   35.00
# 6     1965-01-12 00:00:00+00:00  13:32:25   27.3570    87.8670   20.00
# 7     1965-01-15 00:00:00+00:00  23:17:42  -13.3090   166.2120   35.00
# 8     1965-01-16 00:00:00+00:00  11:32:37  -56.4520   -27.0430   95.00
# 9     1965-01-17 00:00:00+00:00  10:43:17  -24.5630   178.4870  565.00
# 10    1965-01-17 00:00:00+00:00  20:57:41   -6.8070   108.9880  227.90
# 11    1965-01-24 00:00:00+00:00  00:11:17   -2.6080   125.9520   20.00
# ...

# %%
eq_filtered.dtypes
# Out:
# Date         datetime64[ns, UTC]
# Time                      object
# Latitude                 float64
# Longitude                float64
# Depth                    float64
# Type                      object
# Magnitude                float64
# year                       int64
# dtype: object

# %%
eq_filtered["year"]=eq_filtered["Date"].dt.year
#Date=eq_filtered["Date"].dt.year
#Month=eq_filtered["Date"].dt.month
#Day=eq_filtered["Date"].dt.day
#eq_filtered['year'] = eq_filtered.pickup_datetime.apply(lambda t: t.year)
# Out:
# C:\Users\ditsaxen\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
eq_filtered.head(70)
#eq=eq_filtered.set_index(['Date'])
#eq.head(2)
# Out:
#                         Date      Time  Latitude  Longitude  Depth  \
# 0  1965-01-02 00:00:00+00:00  13:44:18    19.246    145.616  131.6
# 1  1965-01-04 00:00:00+00:00  11:29:49     1.863    127.352   80.0
# 2  1965-01-05 00:00:00+00:00  18:05:58   -20.579   -173.972   20.0
# 3  1965-01-08 00:00:00+00:00  18:49:43   -59.076    -23.557   15.0
# 4  1965-01-09 00:00:00+00:00  13:32:50    11.938    126.427   15.0
# 5  1965-01-10 00:00:00+00:00  13:36:32   -13.405    166.629   35.0
# 6  1965-01-12 00:00:00+00:00  13:32:25    27.357     87.867   20.0
# 7  1965-01-15 00:00:00+00:00  23:17:42   -13.309    166.212   35.0
# 8  1965-01-16 00:00:00+00:00  11:32:37   -56.452    -27.043   95.0
# 9  1965-01-17 00:00:00+00:00  10:43:17   -24.563    178.487  565.0
# 10 1965-01-17 00:00:00+00:00  20:57:41    -6.807    108.988  227.9
# 11 1965-01-24 00:00:00+00:00  00:11:17    -2.608    125.952   20.0
# 12 1965-01-29 00:00:00+00:00  09:35:30    54.636    161.703   55.0
# ...

# %%
    plt.figure(figsize=(20,10))
    sns.countplot(x='year',data=eq_filtered)
    plt.xlabel('year')
# Out:
# Text(0.5, 0, 'year')

# %%
eq_filtered["month"]=eq_filtered["Date"].dt.month
eq_filtered.head(5)
# Out:
# C:\Users\ditsaxen\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#                        Date      Time  Latitude  Longitude  Depth        Type  \
# 0 1965-01-02 00:00:00+00:00  13:44:18    19.246    145.616  131.6  Earthquake
# 1 1965-01-04 00:00:00+00:00  11:29:49     1.863    127.352   80.0  Earthquake
# 2 1965-01-05 00:00:00+00:00  18:05:58   -20.579   -173.972   20.0  Earthquake
# 3 1965-01-08 00:00:00+00:00  18:49:43   -59.076    -23.557   15.0  Earthquake
# 4 1965-01-09 00:00:00+00:00  13:32:50    11.938    126.427   15.0  Earthquake
#
#    Magnitude  year  month
# 0        6.0  1965      1
# 1        5.8  1965      1
# ...

# %%
plt.figure(figsize=(20,10))
sns.countplot(x='month',data=eq_filtered)
plt.xlabel('month')
# Out:
# Text(0.5, 0, 'month')

# %%
eq_filtered["Day"]=eq_filtered["Date"].dt.day
eq_filtered.head(5)
# Out:
# C:\Users\ditsaxen\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#                        Date      Time  Latitude  Longitude  Depth        Type  \
# 0 1965-01-02 00:00:00+00:00  13:44:18    19.246    145.616  131.6  Earthquake
# 1 1965-01-04 00:00:00+00:00  11:29:49     1.863    127.352   80.0  Earthquake
# 2 1965-01-05 00:00:00+00:00  18:05:58   -20.579   -173.972   20.0  Earthquake
# 3 1965-01-08 00:00:00+00:00  18:49:43   -59.076    -23.557   15.0  Earthquake
# 4 1965-01-09 00:00:00+00:00  13:32:50    11.938    126.427   15.0  Earthquake
#
#    Magnitude  year  month  Day
# 0        6.0  1965      1    2
# ...

# %%
plt.figure(figsize=(20,10))
sns.countplot(x='Day',data=eq_filtered)
plt.xlabel('Day')
# Out:
# Text(0.5, 0, 'Day')

# %%
eq_filtered['Time']=pd.to_datetime(eq_filtered['Time'],utc=True)
# Out:
# C:\Users\ditsaxen\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
eq_filtered["Hour"]=eq_filtered["Time"].dt.hour
plt.figure(figsize=(20,10))
sns.countplot(x='Hour',data=eq_filtered)
plt.xlabel('Hour')
#Month=eq_filtered["Time"].dt.minute
#Day=eq_filtered["Time"].dt.second
# Out:
# C:\Users\ditsaxen\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# Text(0.5, 0, 'Hour')

# %%
eq_filtered["Minute"]=eq_filtered["Time"].dt.minute
plt.figure(figsize=(20,10))
sns.countplot(x='Minute',data=eq_filtered)
plt.xlabel('Minute')
# Out:
# C:\Users\ditsaxen\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# Text(0.5, 0, 'Minute')

# %%
eq_filtered["Seconds"]=eq_filtered["Time"].dt.second
plt.figure(figsize=(20,10))
sns.countplot(x='Seconds',data=eq_filtered)
plt.xlabel('Seconds')
# Out:
# C:\Users\ditsaxen\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# Text(0.5, 0, 'Seconds')

# %%
def f(x):
     return Series(dict(Number_of_earthquakes = x[['Type']=='Earthquake'].count(), 
                        ))

# %%
df=eq_filtered.groupby('Magnitude')['Date'].count()
df.plot()

# %%
eq_filtered.Magnitude.count()
sns.distplot(eq_filtered['Magnitude'])

# %%
eq_N=eq_filtered[eq_filtered.Latitude>=0]
eq_NE=eq_N[eq_N.Longitude>=0]
eq_NW=eq_N[eq_N.Longitude<=0]

# %%
eq_N.Latitude.count()
sns.distplot(eq_N['Magnitude'])

# %%
eq_S=eq_filtered[eq_filtered.Latitude>=0]
eq_SE=eq_S[eq_S.Longitude>=0]
eq_SW=eq_S[eq_N.Longitude<=0]

# %%
eq_S.Latitude.count()
# Out:
# 10618

# %%
sns.distplot(eq_S['Magnitude'])
